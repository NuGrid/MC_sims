# %% [markdown]
# ## This notebook helps plots [X/Fe] abundances from ppn calculations

# %%
# %pylab nbagg
from scipy import integrate

# The local_utility.py function plot_ppn_xfe_abund doesn't seem to properly work with python3 !!!
# use python2 instead of python3

# python2
import local_utils_python2 as lut
import astronomy as ast
from NuGridPy import utils
from NuGridPy import ppn

# begin counting figures
ifig=0
for i in range(0,10000):
    close(i)
    
    # begin counting figures
ifig=0
for i in range(0,10000):
    close(i)

fsize=16
mpl.rcParams['font.size'] = 10
mpl.rcParams['font.family'] = 'serif'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
CB_color = ['#377eb8', '#ff7f00', '#4daf4a',
            '#f781bf', '#a65628', '#984ea3',
            '#999999', '#e41a1c', '#dede00']

# %%
# specify a path to files with element abundances that will be used for scaling in the plots
# these can be either the solar abundances if you want to plot abundances relative to the solar ones (ref=-1) or
# the initial abundances if you want to plot abundances relative to the initial ones (ref=-2)
#
# the initial abundances are here
init_ab="/Users/dpa/my_github/github_nugrid/NuPPN/frames/mppnp/USEEPP/iniab1.6E-03As09.ppn"
#
# these are the Asplund (2009) solar abundances
sol_ab='/Users/dpa/my_notebooks/iRAWDs_notebooks/'+"iniab1.4E-02As09.ppn"

# %%
ppn_test_dir='/Users/dpa/my_github/github_nugrid/NuPPN/examples/ppn_iprocess_1zone/ppn_run_test_mesa2nd_peak_decayed'

# %%
ifig=ifig+1
close(ifig),lut.select_fig(ifig)

dilution = 0.0147 # this fraction of the final abundances is mixed with the initial ones
dilute_log = np.log10(dilution)

feh_init = -1.6 # [Fe/H] in the initial composition

ppn_cycle=890
lut.plot_ppn_xfe_abund(sol_ab,ppn_test_dir,ppn_cycle,yrange=[-0.5,3.5],zrange=[34,84],\
                       shape=CB_color[1],msize=5,labels=True,label_fsize=12,\
                       dely0=0.15,extr0=-0.05,dilute=dilute_log,feh=feh_init)

plt.minorticks_on();plt.hlines(0,0,85,linestyle='dashed')
tight_layout()
# Out:
# <img src="data:image/png;base64,...">
# WARNING:
# This initial abundance file uses an element name that does
# not contain the mass number in the 3rd to 5th position.
# It is assumed that this is the proton and we will change
# the name to 'h   1' to be consistent with the notation used in
# iniab.dat files
# 892 cycle numbers found in /Users/dpa/my_github/github_nugrid/NuPPN/examples/ppn_iprocess_1zone/ppn_run_test_mesa2nd_peak_decayed
# Ranging from 0 to 891
# Calling get method in cycle mode, adding a_iso_to_plot, z.. el.. isotope.. isotope... to instance
# WARNING: decayed in _getcycle ignores isomers and will decay alpha-unstable p-rich nuclei as if they were beta+ stable.
# Initialising decay index pointers ....
# Th does not exist in this run
# U does not exist in this run
# Can't find element Th in isotopedatabase.txt
# /Users/dpa/nugrid_6050/utils.py:429: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
# ...

# %% [markdown]
# ### For the next reaction flux plot, the file flux_00825.DAT must be in the same directory where this notebook is.

# %%
pp=ppn.abu_vector("/Users/dpa/my_github/github_nugrid/NuPPN/examples/ppn_iprocess_1zone/ppn_run_test_mesa2nd_peak_decayed/")
# Out:
# 892 cycle numbers found in /Users/dpa/my_github/github_nugrid/NuPPN/examples/ppn_iprocess_1zone/ppn_run_test_mesa2nd_peak_decayed/
# Ranging from 00000 to 00891
# Range may not be continuous. To display all available cycles, print <abu_vector_instance>.files

# %%
pp.abu_flux_chart(825,ilabel=False,plotaxis=[77.5,98.5,52.5,62.5],lbound=(-12.5,-4.5),\
                  which_flux=0,prange=5.5,profile='neutron')

tight_layout()
# Out:
# <img src="data:image/png;base64,...">
# flux_00825.DAT
# chart for nucleosynthesis fluxes [dYi/dt]
# flux_00825.DAT  read!
# /Users/dpa/my_github/NuGridPy/data_plot.py:2447: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nzycheck[coord_x_1_small[i],coord_y_1_small[i],0] = 1
# /Users/dpa/my_github/NuGridPy/data_plot.py:2448: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nzycheck[coord_x_1_small[i],coord_y_1_small[i],1] = flux_log10_small[i]
# /Users/dpa/my_github/NuGridPy/data_plot.py:2457: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nzycheck[coord_x_out[i],coord_y_out[i],0] = 1
# /Users/dpa/my_github/NuGridPy/data_plot.py:2458: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ...
