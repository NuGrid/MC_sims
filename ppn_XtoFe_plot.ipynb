# %% [markdown]
# ## This notebook helps plots [X/Fe] abundances from ppn calculations

# %%
# %pylab nbagg
from scipy import integrate

# The local_utility.py function plot_ppn_xfe_abund doesn't seem to properly work with python3 !!!
# use python2 instead of python3
#import local_utils_python3 as lut
#from nugridpy import astronomy as ast
#from nugridpy import utils
#from nugridpy import ppn

# python2
import local_utils_python2 as lut
import astronomy as ast
from NuGridPy import utils
from NuGridPy import ppn

# begin counting figures
ifig=0
for i in range(0,10000):
    close(i)
    
    # begin counting figures
ifig=0
for i in range(0,10000):
    close(i)

fsize=16
mpl.rcParams['font.size'] = 10
mpl.rcParams['font.family'] = 'serif'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
CB_color = ['#377eb8', '#ff7f00', '#4daf4a',
            '#f781bf', '#a65628', '#984ea3',
            '#999999', '#e41a1c', '#dede00']

# %%
# specify a path to files with element abundances that will be used for scaling in the plots
# these can be either the solar abundances if you want to plot abundances relative to the solar ones (ref=-1) or
# the initial abundances if you want to plot abundances relative to the initial ones (ref=-2)
#
# the initial abundances are here
init_ab="iniab1.6E-03As09.ppn"
#
# these are the Asplund (2009) solar abundances
sol_ab='/Users/dpa/my_notebooks/iRAWDs_notebooks/'+"iniab1.4E-02As09.ppn"

# %%
ppn_test_dir='/Users/dpa/my_github/github_nugrid/NuPPN/examples/ppn_iprocess_1zone/ppn_run_test/'

# %%
work_dir='/Users/dpa/Roederer_MC_sims/'
file_name='my_roederer_abund.dat'
f = open(work_dir+file_name, 'r')

z=[]
xfe=[]
yerr=[]
eps=[]
epssol=[]

i=-1
for line in f:
    #print (line)
    if i >= 12:
        z.append(float(line.split()[0]))
        eps.append(float(line.split()[3]))
        xfe.append(float(line.split()[4]))
        yerr.append(float(line.split()[6]))
        epssol.append(float(line.split()[7]))
    i += 1
    
nelem=len(z)
xxsol=np.linspace(0,0,nelem)
print (nelem)
for i in range(nelem):
    xxsol[i]=epssol[i]-eps[i]
    print (i, z[i], xfe[i], yerr[i], eps[i], epssol[i], xxsol[i])
    
f.close()
# Out:
# 56
# (0, 3.0, -99.0, 0.1, 2.03, -99.0, -101.03)
# (1, 6.0, -0.06, 0.2, 6.62, 8.43, 1.8099999999999996)
# (2, 7.0, 0.93, 0.0, 7.01, 7.83, 0.82000000000000028)
# (3, 8.0, 0.62, 0.1, 7.56, 8.69, 1.1299999999999999)
# (4, 11.0, 0.08, 0.15, 4.57, 6.24, 1.6699999999999999)
# (5, 12.0, 0.34, 0.11, 6.19, 7.6, 1.4099999999999993)
# (6, 13.0, 0.08, 0.2, 4.78, 6.45, 1.6699999999999999)
# (7, 14.0, 0.39, 0.2, 6.15, 7.51, 1.3599999999999994)
# (8, 15.0, 0.39, 0.19, 4.05, 5.41, 1.3600000000000003)
# (9, 19.0, 0.33, 0.15, 3.61, 5.03, 1.4200000000000004)
# (10, 20.0, 0.35, 0.15, 4.94, 6.34, 1.3999999999999995)
# (11, 21.0, 0.18, 0.13, 1.71, 3.15, 1.4399999999999999)
# (12, 22.0, 0.41, 0.13, 3.74, 4.95, 1.21)
# (13, 23.0, 0.26, 0.22, 2.57, 3.93, 1.3600000000000003)
# (14, 24.0, 0.36, 0.13, 4.38, 5.64, 1.2599999999999998)
# (15, 25.0, -0.38, 0.11, 3.3, 5.43, 2.1299999999999999)
# (16, 26.0, -1.62, 0.09, 5.88, 7.5, 1.6200000000000001)
# (17, 27.0, -0.12, 0.15, 3.12, 4.99, 1.8700000000000001)
# ...

# %%
ifig=ifig+1
close(ifig),lut.select_fig(ifig)

dilution = 0.0008 # this fraction of the final abundances is mixed with the initial ones
dilute_log = np.log10(dilution)

ppn_cycle=502

lut.plot_ppn_xfe_abund(sol_ab,init_ab,ppn_test_dir,ppn_cycle,yrange=[-2.0,2.0],zrange=[27.5,49.5],\
                       shape='g',msize=5,labels=True,label_fsize=12,\
                       dely0=0.15,extr0=-0.05,dilute=dilution)

ppn_cycle=512

lut.plot_ppn_xfe_abund(sol_ab,init_ab,ppn_test_dir,ppn_cycle,yrange=[-2.0,2.0],zrange=[27.5,49.5],\
                       shape='r',msize=5,labels=False,label_fsize=12,\
                       dely0=0.15,extr0=-0.05,dilute=dilution)

plt.errorbar(z,xfe,yerr,yerr,'ko',markersize=8)

text(28,-1.8,'cycle=502 (green),  cycle=512 (red)',fontsize=14)
#text(30,1.35,'mod=511 (green),  ppn-decayed mod=512 (red),  T_MAX=1.62134D-04',fontsize=14)

#legend('cycle 502','cycle 510')

plt.minorticks_on();plt.hlines(0,0,85,linestyle='dashed')
tight_layout()

#plt.savefig("/Users/dpa/Documents/Roederer_bestfitmod.pdf")
# Out:
# <img src="data:image/png;base64,...">
# WARNING:
# This initial abundance file uses an element name that does
# not contain the mass number in the 3rd to 5th position.
# It is assumed that this is the proton and we will change
# the name to 'h   1' to be consistent with the notation used in
# iniab.dat files
# WARNING:
# This initial abundance file uses an element name that does
# not contain the mass number in the 3rd to 5th position.
# It is assumed that this is the proton and we will change
# the name to 'h   1' to be consistent with the notation used in
# iniab.dat files
# 513 cycle numbers found in /Users/dpa/my_github/github_nugrid/NuPPN/examples/ppn_iprocess_1zone/ppn_run_test/
# Ranging from 0 to 512
# Calling get method in cycle mode, adding a_iso_to_plot, z.. el.. isotope.. isotope... to instance
# WARNING: decayed in _getcycle ignores isomers and will decay alpha-unstable p-rich nuclei as if they were beta+ stable.
# Initialising decay index pointers ....
# ...

# %%
# read in solar abundances in the path sol_ab
utils.solar(sol_ab,1.)
sol_abu=utils.solar_elem_abund
n_sol=len(sol_abu)
print "\nn_sol =",n_sol
# Out:
# WARNING:
# This initial abundance file uses an element name that does
# not contain the mass number in the 3rd to 5th position.
# It is assumed that this is the proton and we will change
# the name to 'h   1' to be consistent with the notation used in
# iniab.dat files
#
# n_sol = 83

# %%
# solar abundances do not include Tc and Pm
# here we include them with the abundances 1e-99

n_el = n_sol+2 # n_sol + the unstable Tc (Z=43) and Pm (Z=61)

el_name=["  " for x in range(n_el)]
z_el=np.linspace(0,0,n_el)

el_name[0]='n'
for i in range(n_el):
    z_el[i]=float(i)       #  Z=i in mppnp surf data output
    if (i>0):
        el_name[i]=utils.get_el_from_z(i)

el_abu_sol = np.linspace(1e-99,1e-99,n_el)
  
for i in range(n_el):  
    for k in range(n_sol):
        z_sol=k+1
        if float(z_sol)==z_el[i] and z_sol != 43 and z_sol != 61:  
            el_abu_sol[i] = sol_abu[k]
            
print "X_sol =",el_abu_sol[1],", X_sol(Tc) =", el_abu_sol[43],", X_sol(Pm) =", el_abu_sol[61]
# Out:
# X_sol = 0.71539998055 , X_sol(Tc) = 1e-99 , X_sol(Pm) = 1e-99

# %%
# check that the decayed abundances are correct by comparing
# them taken directly from an output iso_massf and using the get function
# with decayed=True in plot_ppn_xfe_abund
# cycle 502 has undecayed, while 503 has decayed abundances

ifig=ifig+1
close(ifig),lut.select_fig(ifig)

y_ppn_0 = np.linspace(0,0,n_el)

# read the results of the template run
mc = 502
ppn_file = 'iso_massf'+str(mc).zfill(5)+'.DAT'

f1=open(ppn_test_dir+ppn_file)
lines=f1.readlines()
f1.close()

massfrac=[]
A=[]
Z=[]
element = []
AI = []

for k in range(len(lines)):
    # skip header
    if k<7:
        continue
    
    line=lines[k]
    #print line[0:5].strip(), line[6:12].strip(), line[13:17].strip(),\
    #   line[24:35].strip(), line[37:39].strip(), line[39:43].strip()
    Z.append(line[6:12].strip()) # Z
    A.append(line[13:17].strip()) # A float
    massfrac.append(line[24:35].strip()) # massf
    element.append(line[37:39].strip()) # element (execept NEUT (first) and PROT (second))
    AI.append(line[39:43].strip()) # A integer

nnn = len(A)
element[0] = 'n'
AI[0] = '1'
element[1] = 'H'
AI[1] ='1'
element[nnn-2] = 'ALm'
AI[nnn-2] ='26'
element[nnn-1] = 'KRm'
AI[nnn-1] ='85'

#kp = 10
#print n_ppn
#print kp, float(Z[kp]), float(A[kp]), element[kp], int(AI[kp]), float(massfrac[kp]) 

n = len(A)
z_ppn = np.linspace(0,0,n_el)
y_ppn_0 = np.linspace(0,0,n_el)
j = 0

for i in range(n_el):
    z_ppn[j] = float(i)
    y_ppn_0[j] = 0.
    for kk in range(n):
        if float(Z[kk]) == float(i):
            y_ppn_0[j] += float(massfrac[kk])
    if i != 43 and i != 61:  
        if el_abu_sol[i]>1e-30 and y_ppn_0[j]>1e-30:
            y_ppn_0[j]=np.log10(y_ppn_0[j]/el_abu_sol[i])
    j += 1
    
# read the n_el elemental abundances from 10000 MC runs with randomly varied multiplication factors
# they will be stored in the array el_abu[0:9999,n_el]

#### It is important that the corresponding input data files have numbers from 1 to 10000 !!!!!
#### Therefore, I use mc1=mc+1 in the name of the input file

mc1 = 512
ppn_file = 'iso_massf'+str(mc1).zfill(5)+'.DAT'
#print ppn_file

f1=open(ppn_test_dir+ppn_file)
lines=f1.readlines()
f1.close()

massfrac=[]

for k in range(len(lines)):
    # skip header
    if k<7:
        continue
    
    line=lines[k]
    #print line[0:5].strip(), line[6:12].strip(), line[13:17].strip(),\
    #   line[24:35].strip(), line[37:39].strip(), line[39:43].strip()
    massfrac.append(line[24:35].strip()) # massf

#kp = 10
#print n_ppn
#print kp, float(Z[kp]), float(A[kp]), element[kp], int(AI[kp]), float(massfrac[kp]) 

y_ppn = np.linspace(0,0,n_el)
j = 0
for i in range(n_el):
    y_ppn[j] = 0.
    for kk in range(n):
        if float(Z[kk]) == float(i):
            y_ppn[j] += float(massfrac[kk])
    if i != 43 and i != 61:  
        if el_abu_sol[i]>1e-30 and y_ppn[j]>1e-30:
            y_ppn[j]=np.log10(y_ppn[j]/el_abu_sol[i])
    j += 1
plt.plot(z_ppn,y_ppn,color='r',linewidth=1)
        
#plt.plot(z_ppn,y_ppn_0,color=CB_color[2],linewidth=1)

dilution = 1.0 # 0.0008 # this fraction of the final abundances is mixed with the initial ones
dilute_log = np.log10(dilution)

ppn_cycle=512

# the argument keysol=0 excludes subtracting of the Fe abundance ratio, which allows
# to plot just the solar-scaled abundances

lut.plot_ppn_xfe_abund(sol_ab,init_ab,ppn_test_dir,ppn_cycle,yrange=[-0.8,3],zrange=[29,51],\
                       shape='b--',msize=5,labels=False,label_fsize=12,\
                       dely0=0.15,extr0=-0.05,dilute=dilution,keysol=0)

#plot(z,xxsol,'ko',markersize=8)
xobs = np.linspace(0,0,nelem)
for i in range(nelem):
    xobs[i] = eps[i]-epssol[i]+1.6
#plot(z,xobs,'ko',markersize=8)

plt.xlabel('$Z$',fontsize=fsize)
plt.ylabel('$\log_{10}\ X/X_\odot$',fontsize=fsize)
    
plt.xlim(29,51)
plt.ylim(-0.8,3)
plt.hlines(0,0,85,linestyle='dashed')
plt.minorticks_on()

#label1 = "The benchmark one-zone model (cycle 891)"
#label2 = "The MC one-zone simulations (cycle 891)"
#plt.legend((label1,label2),loc=2,numpoints=1,frameon=False,fontsize=14)

tight_layout()
#plt.savefig("/Users/dpa/Documents/RAWD_MC_sims_results/fig_MC_1zone.pdf")
# Out:
# <img src="data:image/png;base64,...">
# WARNING:
# This initial abundance file uses an element name that does
# not contain the mass number in the 3rd to 5th position.
# It is assumed that this is the proton and we will change
# the name to 'h   1' to be consistent with the notation used in
# iniab.dat files
# WARNING:
# This initial abundance file uses an element name that does
# not contain the mass number in the 3rd to 5th position.
# It is assumed that this is the proton and we will change
# the name to 'h   1' to be consistent with the notation used in
# iniab.dat files
# 513 cycle numbers found in /Users/dpa/my_github/github_nugrid/NuPPN/examples/ppn_iprocess_1zone/ppn_run_test/
# Ranging from 0 to 512
# Calling get method in cycle mode, adding a_iso_to_plot, z.. el.. isotope.. isotope... to instance
# WARNING: decayed in _getcycle ignores isomers and will decay alpha-unstable p-rich nuclei as if they were beta+ stable.
# Initialising decay index pointers ....
# ...

# %% [markdown]
# ### For the next reaction flux plot, the file flux_00825.DAT must be in the same directory where this notebook is.

# %%
pp=ppn.abu_vector("/Users/dpa/my_github/github_nugrid/NuPPN/examples/ppn_iprocess_1zone/ppn_run_test/")

# %%
pp.abu_flux_chart(502,ilabel=False,plotaxis=[33.5,60.5,26.5,37.5],lbound=(-11.5,-4.5),\
                  which_flux=0,prange=5.0,profile='neutron')

#tight_layout()

#plt.savefig("/Users/dpa/Documents/Roederer_bestfitmod_fluxes1.pdf")

# %%
pp.abu_flux_chart(502,ilabel=False,plotaxis=[56.5,84.5,36.5,48.5],lbound=(-11.5,-4.5),\
                  which_flux=0,prange=5.0,profile='neutron')

#tight_layout()

#plt.savefig("/Users/dpa/Documents/Roederer_bestfitmod_fluxes2.pdf")
